# %%
# create population density and covid case dataframes by county to merge
pop_df = pd.read_excel('county_populations.xlsm')
county_df = pd.read_csv('us-counties.csv')
density_df = pd.read_excel('Population_Density.xlsm')

# %%
# create population density and covid case dataframes by county to merge
pop_df = pd.read_excel('county_populations.xlsm')
county_df = pd.read_csv('us-counties.csv')
density_df = pd.read_excel('Population_Density')

# %%
pop_df = pop_df.set_index('FIPS Code')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-1390e5c67b78> in <module>
# ----> 1 pop_df = pop_df.set_index('FIPS Code')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['FIPS Code'] are in the columns"

# %%
county_df = county_df.set_index('fips')

density_df = density_df.set_index('FIPS')

# %%
meta_df = pop_df.join(county_df, how = 'inner')

agg_df = meta_df.join(density_df, how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-3fe0fadf7e93> in <module>
#       1 meta_df = pop_df.join(county_df, how = 'inner')
#       2
# ----> 3 agg_df = meta_df.join(density_df, how = 'inner')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7207         """
#    7208         return self._join_compat(
# -> 7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#    7211
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7230                 right_index=True,
#    7231                 suffixes=(lsuffix, rsuffix),
# -> 7232                 sort=sort,
#    7233             )
#    7234         else:
#
# ...

# %%
density_df
# Out:
#          State            Area       FIPS                    Units  \
# 0          NaN             NaN        NaN                      NaN
# 1          NaN             NaN        NaN                      NaN
# 2          NaN             NaN        NaN                      NaN
# 3          NaN             NaN        NaN                      NaN
# 4          NaN             NaN        NaN                      NaN
# ...        ...             ...        ...                      ...
# 26007  Wyoming   Weston County    56045.0  Persons per square mile
# 26008  Wyoming  Wheatland town  5683040.0  Persons per square mile
# 26009  Wyoming    Worland city  5684925.0  Persons per square mile
# 26010  Wyoming     Wright town  5685015.0  Persons per square mile
# 26011  Wyoming      Yoder town  5686665.0  Persons per square mile
#
#              2019  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
meta_df = meta_df.drop_duplicates(['county'], keep = 'last')

# %%
meta_df['per_capita'] = meta_df['cases'] / meta_df[2018]

meta_df
# Out:
#                State                                          Area  FIPS Code  \
# 25702  New Hampshire              Washington town(Sullivan County)    3378980
# 25830     New Jersey              Denville township(Morris County)    3417650
# 25939     New Jersey                         Highland Park borough    3431470
# 25994     New Jersey                         Little Silver borough    3440770
# 28057       New York  Unincorporated Oakfield town(Genesee County)    3699990
# ...              ...                                           ...        ...
# 46605        Wyoming                                Wheatland town    5683040
# 46606        Wyoming                                  Worland city    5684925
# 46607        Wyoming                                   Wright town    5685015
# 46608        Wyoming                        Wyoming (state totals)         56
# 46609        Wyoming                                    Yoder town    5686665
#
# ...

# %%
density_df.set_index('FIPS')
# Out:
#              State            Area                    Units        2019  \
# FIPS
# NaN            NaN             NaN                      NaN         NaN
# NaN            NaN             NaN                      NaN         NaN
# NaN            NaN             NaN                      NaN         NaN
# NaN            NaN             NaN                      NaN         NaN
# NaN            NaN             NaN                      NaN         NaN
# ...            ...             ...                      ...         ...
# 56045.0    Wyoming   Weston County  Persons per square mile     2.90533
# 5683040.0  Wyoming  Wheatland town  Persons per square mile   866.58537
# 5684925.0  Wyoming    Worland city  Persons per square mile  1105.66449
# 5685015.0  Wyoming     Wright town  Persons per square mile   608.07018
# 5686665.0  Wyoming      Yoder town  Persons per square mile   742.85714
#
#            Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# FIPS
# ...

# %%
agg_df = meta_df.join(density_df, how = 'inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e58870bcd0a0> in <module>
# ----> 1 agg_df = meta_df.join(density_df, how = 'inner')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7207         """
#    7208         return self._join_compat(
# -> 7209             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7210         )
#    7211
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7230                 right_index=True,
#    7231                 suffixes=(lsuffix, rsuffix),
# -> 7232                 sort=sort,
#    7233             )
#    7234         else:
#
# ...

# %%
pop_list = meta_df[2018].to_list()

cases_list = meta_df['cases'].to_list()

# %%
correlation = stats.pearsonr(pop_list,cases_list)

correlation
# Out:
# (0.5353508967189947, 6.077928386705101e-123)

# %%
plt.figure(figsize=(20,10))

plt.scatter(pop_list, cases_list, marker="o", facecolors="red", edgecolors="black",
            alpha=.75)
